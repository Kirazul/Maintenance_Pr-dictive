# %% [markdown]
# # Predictive Maintenance Workflow Book
#
# This notebook documents the maintenance pipeline used by the `maintenance/` product application.

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd()
print('Project root ready')
# Out:
# Project root ready

# %%
stages = ['discovery', 'cleaning', 'split', 'features', 'training', 'evaluation', 'frontend']
print('Pipeline stages documented')
# Out:
# Pipeline stages documented
